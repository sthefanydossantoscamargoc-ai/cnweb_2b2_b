# %% [markdown]
# <a href="https://colab.research.google.com/github/sthefanydossantoscamargoc-ai/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velmedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ' ,calcVelMedia(50, 4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_619/1971365111.py in <cell line: 0>()
# ----> 1 print('Velocidade Média: ' ,calcVelMedia(50, 4))
#
# /tmp/ipykernel_619/3064897616.py in calcVelMedia(deltaS, deltaT)
#       1 def calcVelMedia(deltaS, deltaT):
#       2   velMedia = (deltaS / deltaT)
# ----> 3   return velmedia
#
# NameError: name 'velmedia' is not defined
